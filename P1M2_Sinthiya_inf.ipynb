# %%
# load objek model, scaler, dan ohc yang telah disimpan
with open("final_model.pkl", "rb") as f:
    final_model = pickle.load(f)

# %%
# membuat data dummy
np.random.seed(0)


cat = ['No', 'Yes','No internet service']
bin=['Yes','No']
ct=['Month-to-month', 'One year', 'Two year']
data = {
    'SeniorCitizen': np.random.randint(0,2, 10),
    'Partner': np.random.choice(bin, 10),
    'Dependents': np.random.choice(bin, 10),
    'OnlineSecurity': np.random.choice(cat, 10),
    'OnlineBackup': np.random.choice(cat, 10),
    'DeviceProtection': np.random.choice(cat, 10),
    'TechSupport': np.random.choice(cat, 10),
    'Contract': np.random.choice(ct, 10),
    'PaperlessBilling': np.random.choice(bin, 10),
    'tenure': np.random.randint(1, 72, 10),
    'MonthlyCharges': np.random.uniform(18.25,118.75, 10),
    }

# %%
# membuat dataframe
data_inf = pd.DataFrame(data)

# %%
data_inf
# Out:
#    SeniorCitizen Partner Dependents       OnlineSecurity         OnlineBackup  \
# 0              0      No        Yes                  Yes  No internet service
# 1              1     Yes         No                   No                   No
# 2              1     Yes         No                   No                  Yes
# 3              0      No        Yes                  Yes                  Yes
# 4              1     Yes        Yes  No internet service                  Yes
# 5              1     Yes         No                   No                   No
# 6              1     Yes         No  No internet service  No internet service
# 7              1     Yes         No                   No                   No
# 8              1     Yes         No                  Yes  No internet service
# 9              1      No        Yes                  Yes  No internet service
#
#       DeviceProtection          TechSupport        Contract PaperlessBilling  \
# ...

# %%
# prediksi pada data inference
prediction = final_model.predict(data_inf)

# %%
data_inf['prediction']=prediction

# %%
data_inf['prediction'] = data_inf['prediction'].apply(lambda x : 'No' if x == 0 else 'Yes')

# %%
data_inf
# Out:
#    SeniorCitizen Partner Dependents       OnlineSecurity         OnlineBackup  \
# 0              0      No        Yes                  Yes  No internet service
# 1              1     Yes         No                   No                   No
# 2              1     Yes         No                   No                  Yes
# 3              0      No        Yes                  Yes                  Yes
# 4              1     Yes        Yes  No internet service                  Yes
# 5              1     Yes         No                   No                   No
# 6              1     Yes         No  No internet service  No internet service
# 7              1     Yes         No                   No                   No
# 8              1     Yes         No                  Yes  No internet service
# 9              1      No        Yes                  Yes  No internet service
#
#       DeviceProtection          TechSupport        Contract PaperlessBilling  \
# ...
